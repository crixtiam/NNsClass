# %%
import csv
lista_columnas = []
lista = []
with open('StudentsPerformance.csv',mode="r",encoding="utf-8") as csv_file:
    csv_reader = csv.DictReader(csv_file)
    line_count = 0

    for row in csv_reader:
        lista.append(row)
        print(row)
    #    if line_count == 0:
    #        lista_columnas.append(row)
    #        print(f'{" ".join(row)}')
    #        line_count = line_count + 1
    #    elif line_count>0:
    #        lista_filas.append([[row[0]],[row[1]],[row[2]],[row[4]],[row[5]]])
    #        #print(f"row product_id {row[0]}")
# Out:
# {'gender': 'female', 'race/ethnicity': 'group B', 'parental level of education': "bachelor's degree", 'lunch': 'standard', 'test preparation course': 'none', 'math score': '72', 'reading score': '72', 'writing score': '74'}
# {'gender': 'female', 'race/ethnicity': 'group C', 'parental level of education': 'some college', 'lunch': 'standard', 'test preparation course': 'completed', 'math score': '69', 'reading score': '90', 'writing score': '88'}
# {'gender': 'female', 'race/ethnicity': 'group B', 'parental level of education': "master's degree", 'lunch': 'standard', 'test preparation course': 'none', 'math score': '90', 'reading score': '95', 'writing score': '93'}
# {'gender': 'male', 'race/ethnicity': 'group A', 'parental level of education': "associate's degree", 'lunch': 'free/reduced', 'test preparation course': 'none', 'math score': '47', 'reading score': '57', 'writing score': '44'}
# ...

# %%
row
# Out:
# {'gender': 'female',
#  'race/ethnicity': 'group D',
#  'parental level of education': 'some college',
#  'lunch': 'free/reduced',
#  'test preparation course': 'none',
#  'math score': '77',
#  'reading score': '86',
#  'writing score': '86'}

# %%
row
# Out:
# {'gender': 'female',
#  'race/ethnicity': 'group D',
#  'parental level of education': 'some college',
#  'lunch': 'free/reduced',
#  'test preparation course': 'none',
#  'math score': '77',
#  'reading score': '86',
#  'writing score': '86'}

# %%
lista[1]
# Out:
# {'gender': 'female',
#  'race/ethnicity': 'group C',
#  'parental level of education': 'some college',
#  'lunch': 'standard',
#  'test preparation course': 'completed',
#  'math score': '69',
#  'reading score': '90',
#  'writing score': '88'}

# %%
for it,valor in enumerate(lista):
    lista[it]["math score"]=float(valor["math score"])
    lista[it]["reading score"]=float(valor["reading score"])
    lista[it]["writing score"]=float(valor["writing score"])

# %%
type(lista[0]["writing score"])
# Out:
# float

# %%
len(lista)
# Out:
# 1000

# %%
row
# Out:
# {'gender': 'female',
#  'race/ethnicity': 'group D',
#  'parental level of education': 'some college',
#  'lunch': 'free/reduced',
#  'test preparation course': 'none',
#  'math score': 77.0,
#  'reading score': 86.0,
#  'writing score': 86.0}

# %%
total_lista = len(lista)
sumador= 0
for valor in lista:
    sumador = sumador + valor["writing score"]

# %%
promedio = sumador/total_lista

# %%
promedio
# Out:
# 68.054

# %%
diccionario = {
    "id": "1",
    "id2":"2"
}

# %%
diccionario["roberto"] = "katherine"

# %%
diccionario
# Out:
# {'id': '1', 'id2': '2', 'roberto': 'katherine'}

# %% [markdown]
# Division

# %%
for it,diccionario in enumerate(lista):
    lista[it]["division_terreno_persona"] = diccionario["writing score"]/diccionario["reading score"]

# %%
lista[2]
# Out:
# {'gender': 'female',
#  'race/ethnicity': 'group B',
#  'parental level of education': "master's degree",
#  'lunch': 'standard',
#  'test preparation course': 'none',
#  'math score': 90.0,
#  'reading score': 95.0,
#  'writing score': 93.0,
#  'division_terreno_persona': 0.9789473684210527}

# %%
lista_maximos=[]
for it,diccionario in enumerate(lista):
    lista_maximos.append(diccionario["math score"])

# %%
for it,valor in enumerate(lista_maximos):

# %%
it = 23
valor = 90
tupla = (it,valor)

# %%
lista[23]
# Out:
# {'gender': 'female',
#  'race/ethnicity': 'group C',
#  'parental level of education': 'some high school',
#  'lunch': 'standard',
#  'test preparation course': 'none',
#  'math score': 69.0,
#  'reading score': 73.0,
#  'writing score': 73.0,
#  'division_terreno_persona': 1.0}

# %%
for it,diccionario in enumerate(lista):
    lista[it]["resta"] = abs(diccionario["writing score"]-diccionario["reading score"])

# %%
abs()

# %%
lista
# Out:
# [{'gender': 'female',
#   'race/ethnicity': 'group B',
#   'parental level of education': "bachelor's degree",
#   'lunch': 'standard',
#   'test preparation course': 'none',
#   'math score': 72.0,
#   'reading score': 72.0,
#   'writing score': 74.0,
#   'resta': 2.0},
#  {'gender': 'female',
#   'race/ethnicity': 'group C',
#   'parental level of education': 'some college',
#   'lunch': 'standard',
#   'test preparation course': 'completed',
#   'math score': 69.0,
#   'reading score': 90.0,
#   'writing score': 88.0,
#   'resta': 2.0},
#  {'gender': 'female',
#   'race/ethnicity': 'group B',
#   'parental level of education': "master's degree",
#   'lunch': 'standard',
#   'test preparation course': 'none',
#   'math score': 90.0,
#   'reading score': 95.0,
#   'writing score': 93.0,
#   'resta': 2.0},
#  {'gender': 'male',
#   'race/ethnicity': 'group A',
#   'parental level of education': "associate's degree",
#   'lunch': 'free/reduced',
#   'test preparation course': 'none',
# ...

# %%
    #for row in csv_reader:
    #    if line_count == 0:
    #        lista_columnas.append(row)
    #        print(f'{" ".join(row)}')
    #        line_count = line_count + 1
    #    elif line_count>0:
    #        lista_filas.append([[row[0]],[row[1]],[row[2]],[row[4]],[row[5]]])
    #        #print(f"row product_id {row[0]}")
